# %% [markdown]
# # Identity Theft Detection EDA\n\nUse this notebook to inspect the Kaggle dataset before training.\n\nSuggested checks:\n- class imbalance\n- missing values\n- distributions of numeric variables\n- suspicious device/location patterns\n

# %%
import pandas as pd\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('../data/raw/identity_fraud.csv')\ndf.head()
