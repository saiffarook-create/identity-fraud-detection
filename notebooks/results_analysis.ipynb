# %% [markdown]
# # Results Analysis\n\nUse this notebook to inspect metrics, sample predictions, and generated figures.

# %%
import json\nfrom pathlib import Path\n\nmetrics = json.loads(Path('artifacts/metrics.json').read_text(encoding='utf-8'))\nmetrics
