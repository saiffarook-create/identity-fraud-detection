# %% [markdown]
# # Model Training Notebook\n\nThis notebook runs the same training logic as the CLI and is useful for demos.

# %%
# !python -m src.training.train --data data/raw/identity_fraud.csv --target is_fraud
